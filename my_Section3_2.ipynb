# %% [markdown]
# <a href="https://colab.research.google.com/github/moya3/test/blob/master/my_Section3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PART2 データをもう少し詳しく見てみよう
# ## おまじない

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## データの読み込み
# - train.csvを読み込みましょう
# - 読み込んだものは変数trainに代入しましょう

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# ## trainの先頭行を見てみましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout  ... payday  weather precipitation temperature
# 0  2013-11-18   90    月        0  ...    NaN       快晴            --        19.8
# 1  2013-11-19  101    火        1  ...    NaN       快晴            --        17.0
# 2  2013-11-20  118    水        0  ...    NaN       快晴            --        15.5
# 3  2013-11-21  120    木        1  ...    NaN       快晴            --        15.2
# 4  2013-11-22  130    金        1  ...    NaN       快晴            --        16.1
#
# [5 rows x 12 columns]

# %% [markdown]
# ## 基本統計量を確認してみましょう
# - describe関数を使います

# %%
train.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %% [markdown]
# ## データの型を確認してみましょう
# - info関数を使います

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           166 non-null    float64
#  6   remarks        21 non-null     object
#  7   event          14 non-null     object
#  8   payday         10 non-null     float64
#  9   weather        207 non-null    object
#  10  precipitation  207 non-null    object
#  11  temperature    207 non-null    float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 19.5+ KB

# %% [markdown]
# ## 1つのカラムだけに注目してみましょう
# - ここでは"y"というカラムを見てみましょう

# %%
train['y']
# Out:
# 0       90
# 1      101
# 2      118
# 3      120
# 4      130
#       ...
# 202     59
# 203     50
# 204     45
# 205     56
# 206     40
# Name: y, Length: 207, dtype: int64

# %% [markdown]
# ## yの平均と中央値を見てみましょう
# - 平均値はmean関数、中央値はmedian関数を使います

# %%
train['y'].mean()
# Out:
# 86.6231884057971

# %%
train['y'].median()
# Out:
# 78.0

# %% [markdown]
# ## yの値が150以上のデータのみを見てみましょう

# %%
train[train['y']>=150]
# Out:
#       datetime    y week  soldout  ... payday  weather precipitation temperature
# 8   2013-11-28  151    木        0  ...    NaN       薄曇            --        17.7
# 10   2013-12-2  151    月        1  ...    NaN       快晴            --        13.8
# 11   2013-12-3  153    火        1  ...    NaN       快晴            --        13.9
# 12   2013-12-4  151    水        1  ...    NaN       晴れ            --        13.5
# 13   2013-12-5  171    木        0  ...    NaN       快晴            --        13.8
# 15   2013-12-9  165    月        1  ...    NaN        曇            --         9.1
# 16  2013-12-10  155    火        0  ...    1.0        曇           0.5         7.1
# 17  2013-12-11  157    水        0  ...    NaN        曇            --        11.0
# 20  2013-12-16  160    月        0  ...    NaN       快晴            --        11.3
# 23  2013-12-19  151    木        0  ...    NaN        雨           0.5         6.8
#
# [10 rows x 12 columns]

# %% [markdown]
# ## 曜日が月となっているデータのみを見てみましょう

# %%
train[train['week']=='月']
# Out:
#        datetime    y week  soldout  ... payday  weather precipitation temperature
# 0    2013-11-18   90    月        0  ...    NaN       快晴            --        19.8
# 5    2013-11-25  135    月        1  ...    NaN        曇            --        14.6
# 10    2013-12-2  151    月        1  ...    NaN       快晴            --        13.8
# 15    2013-12-9  165    月        1  ...    NaN        曇            --         9.1
# 20   2013-12-16  160    月        0  ...    NaN       快晴            --        11.3
# 36    2014-1-20  126    月        1  ...    NaN       晴れ            --         6.5
# 41    2014-1-27  126    月        1  ...    NaN       快晴            --         5.1
# 46     2014-2-3  139    月        1  ...    NaN       晴れ            --        15.9
# 51    2014-2-10  137    月        0  ...    1.0        曇            --         7.8
# 55    2014-2-17  137    月        1  ...    NaN       晴れ            --        11.6
# 60    2014-2-24  129    月        1  ...    NaN        曇            --         6.6
# 65     2014-3-3  131    月        0  ...    NaN        曇            --         7.8
# 70    2014-3-10  123    月        0  ...    1.0        曇            --         7.6
# 75    2014-3-17  129    月        0  ...    NaN       快晴            --        14.0
# 79    2014-3-24  102    月        0  ...    NaN       快晴            --        17.4
# 84    2014-3-31   84    月        0  ...    NaN       晴れ            --        17.5
# 89     2014-4-7  107    月        0  ...    NaN       快晴            --        13.8
# 94    2014-4-14   92    月        0  ...    NaN       晴れ            --        16.4
# 99    2014-4-21  109    月        0  ...    NaN        曇            --        16.4
# 104   2014-4-28   54    月        0  ...    NaN       晴れ            --        22.7
# 111   2014-5-12   73    月        0  ...    NaN       薄曇            --        22.7
# 116   2014-5-19   70    月        1  ...    NaN        曇            --        22.8
# 121   2014-5-26   77    月        1  ...    NaN       薄曇            --        23.9
# 126    2014-6-2   74    月        0  ...    NaN       薄曇            --        30.6
# 131    2014-6-9   74    月        1  ...    NaN        雨             0        25.0
# 136   2014-6-16   76    月        1  ...    NaN       薄曇            --        28.1
# 141   2014-6-23   72    月        0  ...    NaN        曇            --        26.9
# 146   2014-6-30   65    月        0  ...    NaN       薄曇            --        25.5
# 151    2014-7-7   82    月        1  ...    NaN        雨           0.5        24.0
# 156   2014-7-14   65    月        1  ...    NaN       薄曇             0        30.9
# 165   2014-7-28   65    月        1  ...    NaN       晴れ            --        28.9
# 170    2014-8-4   75    月        1  ...    NaN        曇            --        32.7
# 175   2014-8-11   45    月        0  ...    NaN       晴れ            --        32.4
# 177   2014-8-18   56    月        0  ...    NaN        曇            --        32.2
# 182   2014-8-25   55    月        0  ...    NaN        曇             0        26.0
# 187    2014-9-1   65    月        1  ...    NaN        曇            --        23.4
# 192    2014-9-8   68    月        1  ...    NaN        曇            --        23.1
# 201   2014-9-22   29    月        0  ...    NaN       晴れ            --        25.2
# 205   2014-9-29   56    月        1  ...    NaN       快晴            --        26.6
#
# [39 rows x 12 columns]

# %% [markdown]
# ## 曜日が火となっているデータをyで昇順・降順にして見てみましょう
# - ソートはsort_values関数を使います。sort_values(by="XXX")と書きます
# - 降順にしたい場合はカッコの中にオプションとしてascending=Falseを書きます

# %%
train.sort_values(by='week')
# Out:
#        datetime    y week  soldout  ... payday  weather precipitation temperature
# 0    2013-11-18   90    月        0  ...    NaN       快晴            --        19.8
# 205   2014-9-29   56    月        1  ...    NaN       快晴            --        26.6
# 99    2014-4-21  109    月        0  ...    NaN        曇            --        16.4
# 175   2014-8-11   45    月        0  ...    NaN       晴れ            --        32.4
# 187    2014-9-1   65    月        1  ...    NaN        曇            --        23.4
# ..          ...  ...  ...      ...  ...    ...      ...           ...         ...
# 174    2014-8-8  129    金        0  ...    1.0        曇            --        31.1
# 59    2014-2-21  113    金        0  ...    NaN       快晴            --         8.5
# 54    2014-2-14   86    金        1  ...    NaN        雪           0.5         1.2
# 93    2014-4-11  128    金        1  ...    NaN       快晴            --        16.5
# 103   2014-4-25   80    金        0  ...    NaN       晴れ            --        20.8
#
# [207 rows x 12 columns]

# %%
train.sort_values(by='week',ascending=False)
# Out:
#        datetime    y week  soldout  ... payday  weather precipitation temperature
# 103   2014-4-25   80    金        0  ...    NaN       晴れ            --        20.8
# 115   2014-5-16  126    金        0  ...    NaN       快晴            --        23.8
# 31    2014-1-10   87    金        0  ...    1.0       快晴            --         5.1
# 145   2014-6-27   74    金        0  ...    NaN        雨             0        25.4
# 69     2014-3-7   73    金        1  ...    NaN       快晴            --         7.0
# ..          ...  ...  ...      ...  ...    ...      ...           ...         ...
# 104   2014-4-28   54    月        0  ...    NaN       晴れ            --        22.7
# 156   2014-7-14   65    月        1  ...    NaN       薄曇             0        30.9
# 131    2014-6-9   74    月        1  ...    NaN        雨             0        25.0
# 182   2014-8-25   55    月        0  ...    NaN        曇             0        26.0
# 0    2013-11-18   90    月        0  ...    NaN       快晴            --        19.8
#
# [207 rows x 12 columns]

# %% [markdown]
# ## 曜日が月曜日の時のyの平均値を見てみましょう
# - 今までの応用です。まず、trainから曜日が月曜日の条件で抜きだし、yを選択した上で、その後に平均値を求める関数を使います

# %%
train[train['week'] == '月']['y'].mean()
# Out:
# 94.05128205128206

# %% [markdown]
# # 実習

# %% [markdown]
# 1.test.csvを変数testとして読み込もう

# %%
test = pd.read_csv('test.csv')

# %% [markdown]
# 2.testの先頭行を確認しましょう

# %%
test.head()
# Out:
#     datetime week  soldout  ... weather  precipitation temperature
# 0  2014-10-1    水        1  ...       雨              0        20.2
# 1  2014-10-2    木        0  ...       曇             --        23.9
# 2  2014-10-3    金        0  ...      晴れ             --        28.7
# 3  2014-10-6    月        1  ...       雨            0.5        21.5
# 4  2014-10-7    火        0  ...      晴れ             --        22.1
#
# [5 rows x 11 columns]

# %% [markdown]
# 3.testの基本統計量を調べてみよう

# %%
test.describe()
# Out:
#          soldout        kcal  payday  temperature
# count  40.000000   36.000000     2.0    40.000000
# mean    0.425000  421.083333     1.0    18.665000
# std     0.500641   13.626392     0.0     4.401838
# min     0.000000  396.000000     1.0     9.200000
# 25%     0.000000  411.500000     1.0    15.250000
# 50%     0.000000  420.000000     1.0    19.000000
# 75%     1.000000  428.500000     1.0    21.650000
# max     1.000000  460.000000     1.0    28.700000

# %% [markdown]
# 4.trainのtemperatureの平均値を求めてみよう

# %%
train['temperature'].mean()
# Out:
# 19.252173913043478

# %% [markdown]
# 5.trainのtemperatureが平均以上のデータだけを選択してみよう

# %%
train[train['temperature']>=train['temperature'].mean()]
# Out:
#        datetime   y week  soldout  ... payday  weather precipitation temperature
# 0    2013-11-18  90    月        0  ...    NaN       快晴            --        19.8
# 90     2014-4-8  96    火        1  ...    NaN       快晴            --        20.1
# 92    2014-4-10  87    木        0  ...    1.0       晴れ            --        21.3
# 95    2014-4-15  82    火        0  ...    NaN       快晴            --        19.7
# 96    2014-4-16  57    水        0  ...    NaN       薄曇            --        21.5
# ..          ...  ..  ...      ...  ...    ...      ...           ...         ...
# 202   2014-9-24  59    水        1  ...    NaN        曇             0        24.8
# 203   2014-9-25  50    木        0  ...    NaN        曇             0        25.4
# 204   2014-9-26  45    金        0  ...    NaN       晴れ            --        27.1
# 205   2014-9-29  56    月        1  ...    NaN       快晴            --        26.6
# 206   2014-9-30  40    火        0  ...    NaN       快晴            --        28.1
#
# [107 rows x 12 columns]

# %% [markdown]
# 6.trainで今度はyとweekの2つのカラムを選択したい。どうしたらいいだろう？
# - []をもう一つ使う

# %%
train[['y', 'week']]
# Out:
#        y week
# 0     90    月
# 1    101    火
# 2    118    水
# 3    120    木
# 4    130    金
# ..   ...  ...
# 202   59    水
# 203   50    木
# 204   45    金
# 205   56    月
# 206   40    火
#
# [207 rows x 2 columns]
