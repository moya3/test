# %% [markdown]
# <a href="https://colab.research.google.com/github/moya3/test/blob/master/Colaboratory_%E3%81%B8%E3%82%88%E3%81%86%E3%81%93%E3%81%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Colaboratory とは</h1>
#
# Colaboratory（略称: Colab）では、ブラウザから Python を記述し実行できるほか、次の特長を備えています。
# - 構成が不要
# - GPU への無料アクセス
# - 簡単に共有
#
# Colab は、<strong>学生</strong>、<strong>データ サイエンティスト</strong>、<strong>AI リサーチャー</strong>の皆さんの作業を効率化します。詳しくは、<a href="https://www.youtube.com/watch?v=inN8seMm7UI">Colab のご紹介</a>をご覧ください。下からすぐに使ってみることもできます。

# %% [markdown]
# ## <strong>はじめに</strong>
#
# ご覧になっているドキュメントは静的なウェブページではなく、<strong>Colab ノートブック</strong>という、コードを記述して実行できるインタラクティブな環境です。
#
# たとえば次の<strong>コードセル</strong>には、値を計算して変数に保存し、結果を出力する短い Python スクリプトが含まれています。

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# 上記のセルのコードを実行するには、セルをクリックして選択し、コードの左側にある実行ボタンをクリックするか、キーボード ショートカット「command+return」または「Ctrl+Enter」を使用します。コードはセルをクリックしてそのまま編集できます。
#
# 1 つのセルで定義した変数は、後で他のセルで使用できます。

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab ノートブックを使用すると、<strong>画像</strong>、<strong>HTML</strong>、<strong>LaTeX</strong> などと合わせて、<strong>実行可能コード</strong>と<strong>リッチテキスト</strong>を 1 つのドキュメントに結合できます。Colab ノートブックを独自に作成すると、Google ドライブ アカウントに保存されます。Colab ノートブックは、同僚や友人と簡単に共有し、コメントの記入や編集をしてもらうことができます。詳細については <a href="/notebooks/basic_features_overview.ipynb">Colab の概要</a>をご覧ください。新しい Colab ノートブックを作成するには、上にある &#91;ファイル&#93; メニューを使用するか、<a href="http://colab.research.google.com#create=true">新しい Colab ノートブックを作成する</a>をクリックします。
#
# Colab ノートブックは、Colab がホストする Jupyter ノートブックです。Jupyter プロジェクトの詳細については、<a href="https://www.jupyter.org">jupyter.org</a> をご覧ください。

# %% [markdown]
# ## データ サイエンス
#
# Colab では、よく使用されている Python ライブラリの機能をフルに活用して、データの分析と可視化を行えます。以下のコードセルでは、<strong>numpy</strong> を使用してなんらかのランダムデータを生成し、<strong>matplotlib</strong> を使用して可視化しています。コードはセルをクリックしてそのまま編集できます。

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Colab ノートブックには、Google ドライブ アカウントを使用して独自のデータをインポートできます。その場合は、スプレッドシートや GitHub、その他多くのソースからのインポートが可能です。データのインポートについて、またデータ サイエンスで Colab を使用する方法の詳細については、<a href="#working-with-data">データの操作</a>の下にあるリンクをクリックしてください。

# %% [markdown]
# ## 機械学習
#
# Colab を使用すると、画像データセットのインポート、画像分類ツールのトレーニング、モデルの評価をすべて<a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">数行のコード</a>で実行できます。Colab ノートブックは Google のクラウド サーバーでコードを実行します。そのため、パソコンの性能にかかわらず、<a href="#using-accelerated-hardware">GPU や TPU</a> など Google ハードウェアの優れた機能を活用できます。ブラウザさえあればよい時代になったのです。

# %% [markdown]
# Colab は、次に示す用途を含め、機械学習コミュニティで広く使用されています。
# - TensorFlow の概要
# - ニューラル ネットワークの開発とトレーニング
# - TPU を試す
# - AI リサーチの促進
# - チュートリアルの作成
#
# 機械学習への応用例を示す Colab ノートブックのサンプルを見るには、以下の<a href="#machine-learning-examples">機械学習の例</a>をご覧ください。

# %% [markdown]
# ## その他のリソース
#
# ### Colab でのノートブックの操作
# - [Colaboratory の概要](/notebooks/basic_features_overview.ipynb)
# - [markdown のガイド](/notebooks/markdown_guide.ipynb)
# - [ライブラリのインポートと依存関係のインストール](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub でのノートブックの保存と読み込み](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [インタラクティブなフォーム](/notebooks/forms.ipynb)
# - [インタラクティブなウィジェット](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [Colab の TensorFlow 2](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### データの操作
# - [データの読み込み: ドライブ、スプレッドシート、Google Cloud Storage](/notebooks/io.ipynb)
# - [グラフ: データの視覚化](/notebooks/charts.ipynb)
# - [BigQuery を使ってみる](/notebooks/bigquery.ipynb)
#
# ### 機械学習の集中講座
# Google の機械学習に関するオンライン コースからいくつかのノートブックをご紹介します。詳しくは、<a href="https://developers.google.com/machine-learning/crash-course/">全コースのウェブサイト</a>をご覧ください。
# - [pandas の概要](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Tensorflow のコンセプト](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [TensorFlow での最初の手順](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [ニューラル ネットの概要](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [スパースデータと埋め込みの概要](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# <a name="using-accelerated-hardware"></a>
# ### アクセラレータの使用
# - [TensorFlow と GPU](/notebooks/gpu.ipynb)
# - [TensorFlow と TPU](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## 機械学習の例
#
# Colaboratory で実現されたインタラクティブな機械学習解析のさまざまな例を確認するには、<a href="https://aihub.cloud.google.com/">AI Hub</a> プロジェクトをご覧ください。
#
# おすすめの例をご紹介します。
#
# - <a href="https://aihub.cloud.google.com/p/products%2F7f7495dd-6f66-4f8a-8c30-15f211ad6957">ニューラル スタイル転送</a>: ディープ ラーニングを使用して画像間でスタイルを転送します。
# - <a href="https://aihub.cloud.google.com/p/products%2Fcddd17cf-5f86-4ce7-b6b6-03c5e52ee0fb">EZ NSynth</a>: 音声と WaveNet オートエンコーダを合成します。
# - <a href="https://aihub.cloud.google.com/p/products%2F7a0acf15-0be0-41a6-9bdb-5a5abd4e8fbf">Keras と TPU で Fashion MNIST</a>: ファッション関連の画像をディープ ラーニングで分類します。
# - <a href="https://aihub.cloud.google.com/p/products%2Ff9e8fc11-ad0f-410a-bebe-2482066ce570">DeepDream</a>: 独自の写真から DeepDream 画像を生成します。
# - <a href="https://aihub.cloud.google.com/p/products%2Ff5e8dd20-6b34-44a0-bc45-6e345e36a4e7">畳み込み VAE</a>: 手書きの数字の生成モデルを作成します。

# %%
import os
import numpy as np
import pandas as pd
#df = pd.read_excel('工数_安斎哲嗣.xlsm')

# %%
path = "./"
#files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files
files = [file for file in os.listdir(path) if  file.endswith('.xlsm')] # xlsm files
print(files)

df2 = pd.DataFrame()
for file in files:
      df = pd.read_excel(path+"/"+file)
      name = file.replace('.xlsm','').replace('工数_','')
      df['name'] = name
      print(name)
      df2 = pd.concat([df2, df])
df2 = df2[['name','作業日','作業名','工数(予定)','工数(実績)']]   #列を絞る
df2['作業日'] = pd.to_datetime(df2['作業日'])                     #日付オブジェクトに変換
#df2 = df2.loc[~df2['作業日'].isnull()]                           #このやり方以外にもっといいやり方ないか？
df2.dropna(subset=['作業名'], inplace=True)                       #杉本さんのExcel内の日付のみレコード一件を削除
df2.to_csv('abc.csv',encoding='utf_8_sig', index=None)            #一旦csvを作成
df2 = pd.read_csv('abc.csv')

#df['name'].str[1:4]
# Out:
# ['工数_甚沢攻.xlsm', '工数_高橋祥容.xlsm', '工数_鈴木学.xlsm', '工数_神戸智弘.xlsm', '工数_安斎哲嗣.xlsm', '工数_高柳秀信.xlsm', '工数_長野悠子.xlsm', '工数_三輪速人.xlsm', '工数_河村真実.xlsm', '工数_杉本晴美.xlsm', '工数_南幅隆.xlsm', '工数_任冬梅.xlsm']
# 甚沢攻
# 高橋祥容
# 鈴木学
# 神戸智弘
# 安斎哲嗣
# 高柳秀信
# 長野悠子
# 三輪速人
# 河村真実
# 杉本晴美
# 南幅隆
# 任冬梅

# %%
df.isna().sum()
df2.groupby('name').count()
# Out:
#        作業日   作業名  工数(予定)  工数(実績)
# name
# 三輪速人  1214  1214    1214    1214
# 任冬梅   1019  1019    1019    1016
# 南幅隆   2509  2509    1872    2182
# 安斎哲嗣   734   734     623     687
# 杉本晴美  1090  1090    1090    1087
# 河村真実  1598  1598    1592    1594
# 甚沢攻   1733  1733     906     837
# 神戸智弘   717   717     717     717
# 鈴木学   1319  1319    1099    1317
# 長野悠子   253   253     253     253
# 高柳秀信   374   374     374     374
# 高橋祥容  1557  1557    1557    1526

# %%
#df2.loc[df2.name=='杉本晴美'].isna().sum()


#df2.loc[(df.name.str.contains('杉本'))& (df.作業日=='2020-05-07')]

#df2.loc[df2.作業日=='2020-2-07', ['作業日', '作業名', 'name']]
#df2.loc[df2.作業日=='2020-2-07']
#df2.loc[df2.作業日=='2020-2-07']
df2.loc[(df2.作業日>='2020-05-15')&(df2.作業日<='2021-05-15'), ['name', '作業日', '作業名','工数(予定)','工数(実績)' ]]
# Out:
#        name         作業日                        作業名 工数(予定)              工数(実績)
# 1729    甚沢攻  2020-05-15                    RPA関係作業      1                 0.5
# 1730    甚沢攻  2020-05-15               SDPDM関係打ち合わせ      2                 2.0
# 1731    甚沢攻  2020-05-15          E事業本部 ERP導入 フェーズ2      2                 2.0
# 1732    甚沢攻  2020-05-15                   VDI打ち合わせ      2                 2.0
# 3252   高橋祥容  2020-05-15                    開発標準見直し    2.0                 2.0
# 3253   高橋祥容  2020-05-15  案件見積・部品交換見積 システム把握・手順書等作成    1.0                 0.5
# 3254   高橋祥容  2020-05-15                  SAP日次チェック    0.5                 0.5
# 3255   高橋祥容  2020-05-15          週次予定作成/グループ週報更新など    0.5                 0.5
# 3256   高橋祥容  2020-05-15              日立物流IFプログラム改善    2.0                 2.0
# 3257   高橋祥容  2020-05-15       MED販売管理　装置/部品交換見積の終了    1.0                 1.5
# 7896   三輪速人  2020-05-15                MGソフトサーバー構築    2.0                 0.0
# 7897   三輪速人  2020-05-15                   VDI他部署展開    2.5                2.52
# 7898   三輪速人  2020-05-15                    問い合わせ対応    1.0                 3.0
# 7899   三輪速人  2020-05-15              MG在宅勤務問い合わせ対応    0.0                 1.0
# 7900   三輪速人  2020-05-15                         庶務    0.5                 1.0
# 10586  杉本晴美  2020-05-15           M084用のクエリなど資料まとめ    6.0                 NaN
# 10587  杉本晴美  2020-05-15            SalesCloud打ち合わせ    1.0                 1.0
# 10588  杉本晴美  2020-05-15                       週報作成    0.5                 NaN
# 13093   南幅隆  2020-05-15                  毎日のチェック作業    0.9                 0.9
# 13094   南幅隆  2020-05-15                   MGPC設定作業      4                 4.5
# 13095   南幅隆  2020-05-15                    投融資WF修正      1                   1
# 13096   南幅隆  2020-05-15                       週報作成    0.5                 0.5
# 13097   南幅隆  2020-05-15                   スケジュール作成    0.5                 0.5
# 14109   任冬梅  2020-05-15               フォーキャストSPの修正    2.0                 2.0
# 14110   任冬梅  2020-05-15             イスルさんCSI開発フォロー    0.5                 0.8
# 14111   任冬梅  2020-05-15                CSIサーバ構築MTG    1.0                 1.0
# 14112   任冬梅  2020-05-15                   航空宇宙業務整理    2.5                 1.5
# 14113   任冬梅  2020-05-15           フォーキャストDBとエクセル勉強    1.0                 0.5
# 14114   任冬梅  2020-05-15                 週報、日報・TW報告    0.5                 0.5
# 14115   任冬梅  2020-05-15                CSI開発見積もりの件    0.0                 0.5
# 14116   任冬梅  2020-05-15                Hinemos設定勉強    0.0                 0.7

# %%
#df2.groupby(['作業日','name']).sum()
#df2.groupby(['name']).get_group('高橋祥容')


def my_mean(s):
    """わざとらしいサンプル"""
    return np.mean(s)

df2.groupby(['週','name']).agg({'工数(予定)': my_mean, '工数(実績)': np.sum})
df2.loc[(df2.name.str.contains('高橋'))&(df2.週==20)]
# Out:
#             作業日                        作業名  工数(予定)  ...   予定  weekno yoube
# 1490 2020-05-11  案件見積・部品交換見積 システム把握・手順書等作成     2.0  ...  NaN       0     0
# 1491 2020-05-11              日立物流IFプログラム改善     2.0  ...  NaN       0     0
# 1492 2020-05-11          週次予定作成/グループ週報更新など     0.5  ...  NaN       0     0
# 1493 2020-05-11                  SAP日次チェック     0.5  ...  NaN       0     0
# 1494 2020-05-11                    BASIS作業     1.0  ...  NaN       0     0
# 1495 2020-05-11               見積システムサーバー保守     1.0  ...  NaN       0     0
# 1496 2020-05-11                 SFDC　問合せ対応     0.0  ...  NaN       0     0
# 1497 2020-05-11             航空宇宙　支払検収通知書改修     0.0  ...  NaN       0     0
# 1498 2020-05-11              宮崎日機装購買システム保守     0.0  ...  NaN       0     0
# 1499 2020-05-12  案件見積・部品交換見積 システム把握・手順書等作成     2.0  ...  NaN       1     1
# 1500 2020-05-12              日立物流IFプログラム改善     2.0  ...  NaN       1     1
# 1501 2020-05-12                  SAP日次チェック     0.5  ...  NaN       1     1
# 1502 2020-05-12         MEDICAL SERVER移行作業     1.0  ...  NaN       1     1
# 1503 2020-05-12                   ロット管理化対応     1.0  ...  NaN       1     1
# 1504 2020-05-12                    BASIS作業     1.0  ...  NaN       1     1
# 1505 2020-05-13  案件見積・部品交換見積 システム把握・手順書等作成     1.0  ...  NaN       2     2
# 1506 2020-05-13              日立物流IFプログラム改善     2.0  ...  NaN       2     2
# 1507 2020-05-13                  SAP日次チェック     0.5  ...  NaN       2     2
# 1508 2020-05-13       MED販売管理　装置/部品交換見積の終了     1.0  ...  NaN       2     2
# 1509 2020-05-13              宮崎日機装購買システム保守     1.0  ...  NaN       2     2
# 1510 2020-05-13                     IT統制関連     1.0  ...  NaN       2     2
# 1511 2020-05-13             航空宇宙　支払検収通知書改修     0.5  ...  NaN       2     2
# 1512 2020-05-14                    開発標準見直し     3.0  ...  NaN       3     3
# 1513 2020-05-14  案件見積・部品交換見積 システム把握・手順書等作成     1.0  ...  NaN       3     3
# 1514 2020-05-14                  SAP日次チェック     0.5  ...  NaN       3     3
# 1515 2020-05-14              日立物流IFプログラム改善     1.0  ...  NaN       3     3
# 1516 2020-05-14       MED販売管理　装置/部品交換見積の終了     1.0  ...  NaN       3     3
# 1517 2020-05-14              宮崎日機装購買システム保守     0.5  ...  NaN       3     3
# 1518 2020-05-14                 SFDC　問合せ対応     0.0  ...  NaN       3     3
# 1519 2020-05-15                    開発標準見直し     2.0  ...  NaN       4     4
# 1520 2020-05-15  案件見積・部品交換見積 システム把握・手順書等作成     1.0  ...  NaN       4     4
# 1521 2020-05-15                  SAP日次チェック     0.5  ...  NaN       4     4
# 1522 2020-05-15          週次予定作成/グループ週報更新など     0.5  ...  NaN       4     4
# 1523 2020-05-15              日立物流IFプログラム改善     2.0  ...  NaN       4     4
# 1524 2020-05-15       MED販売管理　装置/部品交換見積の終了     1.0  ...  NaN       4     4
# 1525 2020-05-15              宮崎日機装購買システム保守     0.5  ...  NaN       4     4
#
# [36 rows x 23 columns]

# %%
#df2['yoube'] = df2.作業日.dt.dayofweek
df2.作業日.dt.week
# Out:
# 0       23
# 1       23
# 2       23
# 3       23
# 4       23
#         ..
# 3884    20
# 3885    20
# 3886    20
# 3887    20
# 3888    20
# Name: 作業日, Length: 3889, dtype: int64

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame()
#df['Date'] = df['Date'].apply(pd.datetools.normalize_date)
df2.pivot_table(index='週', columns='name', values='工数(予定)',aggfunc=sum).plot()
#df2.pivot_table(index='週', columns='name', values='工数(予定)')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36913 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21987 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27827 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30495 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27211 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36913 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23433 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21987 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27827 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23455 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27211 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23481 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import datetime

# %%
pd.to_datetime(['2014-11-09 10:00', '2014-11-10 10:00'])
# Out:
# DatetimeIndex(['2014-11-09 10:00:00', '2014-11-10 10:00:00'], dtype='datetime64[ns]', freq=None)

# %%
dt = pd.to_datetime('2020-5-16 9:40:3')

# %%
datetime.datetime.today()
# Out:
# datetime.datetime(2020, 5, 16, 0, 12, 23, 119088)

# %%
dt.tz_localize('Asia/Tokyo')
# Out:
# Timestamp('2020-05-16 09:40:03+0900', tz='Asia/Tokyo')

# %%
dt
# Out:
# Timestamp('2020-05-16 09:40:03')
